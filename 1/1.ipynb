# %%
library(tidyverse)
# Out:
# Loading tidyverse: ggplot2
# Loading tidyverse: tibble
# Loading tidyverse: tidyr
# Loading tidyverse: readr
# Loading tidyverse: purrr
# Loading tidyverse: dplyr
# Warning message:
# "package 'tidyr' was built under R version 3.4.3"Conflicts with tidy packages ---------------------------------------------------
# filter(): dplyr, stats
# lag():    dplyr, stats

# %%
dim(mpg)
# Out:
# [1] 234  11

# %%
ggplot(data = mpg) + 
geom_point(mapping = aes(x = displ, y = hwy), shape = 22, color = 'red', fill = 'blue')
# Out:
# plot without title

# %%
dim(mpg)
# Out:
# Error in eval(expr, envir, enclos): object 'mpg' not found
# Traceback:

# %%
ggplot(data = mpg) + 
geom_point(mapping = aes(x = displ, y = hwy)) +
facet_wrap(~ displ)
# Out:
# plot without title

# %%
ggplot(data = mpg) + 
geom_point(mapping = aes(x = displ, y = hwy)) +
facet_grid(drv ~ cyl)
# Out:
# plot without title

# %%
ggplot(data = mpg) +
geom_point(mapping = aes(x = drv, y = cyl))
# Out:
# plot without title

# %%
ggplot(data = mpg) + 
geom_point(mapping = aes(x = displ, y = hwy)) +
facet_grid(drv ~ cyl)
# Out:
# plot without title

# %%
ggplot(data = mpg) + 
geom_point(mapping = aes(x = displ, y = hwy)) +
facet_grid(drv ~ cyl, as.table = FALSE)
# Out:
# plot without title

# %%
?facet_grid

# %%
length(shapes)
# Out:
# [1] 234

# %%
shapes <- c(rep(1:24, 234%/%24), 1:(234%%24))

# %%
length(shapes)
# Out:
# [1] 234

# %%
ggplot(data = mpg) + 
geom_point(mapping = aes(x = hwy, y = cyl))
# Out:
# plot without title

# %%
ggplot(data = mpg) + 
geom_point(mapping = aes(x = class, y = drv))
# Out:
# plot without title

# %%
# 1
ggplot(data = mpg) + 
geom_point(mapping = aes(x = displ, y = hwy, color = 'blue'))
# Out:
# plot without title

# %%
ggplot(data = mpg) + 
geom_point(mapping = aes(x = displ, y = hwy, color = rep_len('blue', 234)))
# Out:
# plot without title

# %%
sapply(mpg, class)
# Out:
# manufacturer        model        displ         year          cyl        trans
#  "character"  "character"    "numeric"    "integer"    "integer"  "character"
#          drv          cty          hwy           fl        class
#  "character"    "integer"    "integer"  "character"  "character"

# %%
mpg
# Out:
#     manufacturer model              displ year cyl trans      drv cty hwy fl
# 1   audi         a4                 1.8   1999 4   auto(l5)   f   18  29  p
# 2   audi         a4                 1.8   1999 4   manual(m5) f   21  29  p
# 3   audi         a4                 2.0   2008 4   manual(m6) f   20  31  p
# 4   audi         a4                 2.0   2008 4   auto(av)   f   21  30  p
# 5   audi         a4                 2.8   1999 6   auto(l5)   f   16  26  p
# 6   audi         a4                 2.8   1999 6   manual(m5) f   18  26  p
# 7   audi         a4                 3.1   2008 6   auto(av)   f   18  27  p
# 8   audi         a4 quattro         1.8   1999 4   manual(m5) 4   18  26  p
# 9   audi         a4 quattro         1.8   1999 4   auto(l5)   4   16  25  p
# 10  audi         a4 quattro         2.0   2008 4   manual(m6) 4   20  28  p
# 11  audi         a4 quattro         2.0   2008 4   auto(s6)   4   19  27  p
# ...

# %%
ggplot(data = mpg) +
geom_smooth(mapping = aes(x = displ, y = hwy, color = drv)) +
geom_point(mapping = aes(x = displ, y = hwy, color = drv))
# Out:
# `geom_smooth()` using method = 'loess'
# plot without title

# %%
ggplot(data = mpg) +
geom_smooth(mapping = aes(x = displ, y = hwy, group = drv))
# Out:
# `geom_smooth()` using method = 'loess'
# plot without title

# %%
names(mpg)
# Out:
#  [1] "manufacturer" "model"        "displ"        "year"         "cyl"
#  [6] "trans"        "drv"          "cty"          "hwy"          "fl"
# [11] "class"

# %%
ggplot(data = mpg) +
geom_smooth(mapping = aes(x = cyl, y = hwy))
# Out:
# `geom_smooth()` using method = 'loess'
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# "pseudoinverse used at 6"Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# "neighborhood radius 2"Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# "reciprocal condition number  3.2687e-015"Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# "pseudoinverse used at 6"Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# "neighborhood radius 2"Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# ...

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) +
geom_line(mapping = aes(color = class)) +
geom_smooth(data = filter(mpg, class == 'subcompact'))
# Out:
# `geom_smooth()` using method = 'loess'
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy, color = drv)) +
geom_point() + geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess'
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy, color = drv)) +
geom_point() + geom_smooth(se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess'
# plot without title

# %%
# 6
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) +
geom_point() + 
geom_smooth(se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess'
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) +
geom_point() + 
geom_smooth(se = FALSE, mapping = aes(group = drv))
# Out:
# `geom_smooth()` using method = 'loess'
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy, color = drv)) +
geom_point() + 
geom_smooth(se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess'
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) +
geom_point(mapping = aes(color = drv)) + 
geom_smooth(se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess'
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) +
geom_point(mapping = aes(color = drv)) + 
geom_smooth(se = FALSE, mapping = aes(linetype = drv))
# Out:
# `geom_smooth()` using method = 'loess'
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) +
geom_point(mapping = aes(fill = drv), 
           color = 'white', shape = 21, size = 3, stroke = 2)
# Out:
# plot without title

# %%
diamonds %>% group_by(cut) %>% count
# Out:
#   cut       n
# 1 Fair       1610
# 2 Good       4906
# 3 Very Good 12082
# 4 Premium   13791
# 5 Ideal     21551

# %%
demo <- tribble(
~a, ~b,
'bar 1', 20,
'bar 2', 30,
'bar 3', 40)

ggplot(data = demo) +
geom_bar(mapping = aes(x = a, y = b), stat = 'identity')
# Out:
# plot without title

# %%
?geom_pointrange

# %%
?stat_summary

# %%
?geom_freqpoly

# %%
ggplot(data = diamonds) +
geom_pointrange(mapping = aes(x = cut, y = depth),
                stat = 'summary',
                fun.ymin = min,
                fun.ymax = max,
                fun.y = median)
# Out:
# plot without title

# %%
ggplot(data = diamonds) +
geom_bar(mapping = aes(x = cut, y = ..prop.., fill = color, group = color))
# Out:
# plot without title

# %%
ggplot(data = diamonds) +
geom_bar(mapping = aes(x = cut, y = ..prop.., group = 1))
# Out:
# plot without title

# %%
ggplot(data = diamonds) +
geom_bar(mapping = aes(x = cut, fill = color))
# Out:
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = cty, y = hwy)) +
geom_count()
# Out:
# plot without title

# %%
ggplot(data = mpg) +
geom_boxplot(mapping = aes(x = class, y = displ), position = 'identity')
# Out:
# plot without title

# %%
nz <- map_data('nz')
names(nz)
# Out:
# Attaching package: 'maps'
#
# The following object is masked from 'package:purrr':
#
#     map
# [1] "long"      "lat"       "group"     "order"     "region"    "subregion"

# %%
ggplot(nz, mapping = aes(x = long, y = lat, group = group)) + 
geom_polygon(fill = 'white', color = 'black') +
coord_quickmap()
# Out:
# plot without title

# %%
ggplot(data = diamonds) +
geom_bar(mapping = aes(x = 'Diamond cut', fill = cut), position = 'fill',
        width = 1) +
coord_polar(theta = "y")
# Out:
# plot without title

# %%
?coord_quickmap

# %%
ggplot(data = mpg, mapping = aes(cty, hwy)) +
geom_point() + geom_abline() + coord_fixed()
# Out:
# plot without title

# %%
ggplot(data = diamonds) +
stat_count(mapping = aes(x = cut, fill = ..count..))
# Out:
# plot without title

# %%
?geom_bar
